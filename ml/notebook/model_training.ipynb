# %%
import pandas as pd

df = pd.read_csv("/Users/miriambenali/Desktop/Project-Simplon/HR-pulse-ai-platform/data/processed_data/processed_data.csv")
df.head(5)
# Out:
#    index              Job Title  \
# 0      0  senior data scientist
# 1      1         data scientist
# 2      2         data scientist
# 3      3         data scientist
# 4      4         data scientist
#
#                                      Job Description           Company Name  \
# 0  descriptionthe senior data scientist is respon...         healthfirst3.1
# 1  secure our nation, ignite your futurejoin the ...             mantech4.2
# 2  overviewanalysis group is one of the largest i...      analysis group3.8
# 3  job description:do you have a passion for data...             inficon3.5
# 4  data scientistaffinity solutions  marketing cl...  affinity solutions2.9
#
#                                Industry             Sector  mean_salary
# 0                    insurance carriers          insurance    11.944708
# 1                 research  development  business services    11.944708
# 2                            consulting  business services    11.944708
# 3  electrical  electronic manufacturing      manufacturing    11.944708
# 4                advertising  marketing  business services    11.944708

# %%
x = df

# %%
from sklearn.ensemble import RandomForestRegressor
